# %% [markdown]
# # Lab Assignment 2 - Alyssa Vallery
# ####     210013982
# ####   Link to GitHub Repository - https://github.com/alyssavallery/MyFirstRepo

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")

# %% [markdown]
# ## Part 1: Python Basics

# %% [markdown]
# ##### Task 1:

# %%
#define a function to test if a number is divisible by three (using the % to find is the remainder when divided by three is equal to zero) and print an appropriate message 
def divisibility_by_three(n):
    if n % 3 == 0:
        print(str(n) + " is divisible by 3")
    else:
        print(str(n) + " is not divisible by three")

# test the function using 15 as an example number 
divisibility_by_three(15)
# Out:
# 15 is divisible by 3

# %% [markdown]
# ##### Task 2:

# %%
# Define a function to test if a given fruit is found in the list of acceptable fruits, the function takes the fruit as an input and then an if ... else statement is used to determine what statement should be printed 
def test_fruit(fruit):
    acceptable_fruits = ["apple", "orange", "pear", "kiwi", "strawberry"]
    
    if fruit.lower() in acceptable_fruits:
        print(str(fruit) + " is acceptable.")
    else:
        print(str(fruit) + " is not acceptable.")

# Test the function 
test_fruit("Banana")
# Out:
# Banana is not acceptable.

# %% [markdown]
# ##### Task 3:

# %%
import math as m

# define the haversine formula as a function 
def haversine(coord1, coord2):
    R = 6371.0

    # Coordinates in decimal degrees (latitude, longitude)
    lat1, lon1 = coord1
    lat2, lon2 = coord2

    # Convert latitude and longitude from degrees to radians
    radians1 = m.radians(lat1)
    radians2 = m.radians(lat2)
    delta_phi = m.radians(lat2 - lat1)
    delta_lambda = m.radians(lon2 - lon1)

    # Haversine formula
    a = m.sin(delta_phi / 2)**2 + m.cos(radians1) * m.cos(radians2) * m.sin(delta_lambda / 2)**2
    c = 2 * m.atan2(m.sqrt(a), m.sqrt(1 - a))

   # Distance in kilometers, rounded to two decimal places
    distance = round(R * c, 2)


    return str(distance) + " km"

# Test the function with Edinburgh and London as an example  
coord1 = [55.9533, -3.1882]  # Latitude and Longitude of Edinburgh
coord2 = [51.5074, -0.1278]       # Latitude and Longitude of London

haversine(coord1, coord2)
# Out:
# '533.65 km'

# %% [markdown]
# ## Part 2: Pandas and NumPy

# %%
import numpy as np
import pandas as pd

# %%
# use pandas to read the csv file 
trees_df = pd.read_csv('/arcgis/home/assignment2/portland_park_trees.csv', sep=",", header=0, encoding="ISO-8859-1")

# display the first 5 rows of the dataset 
trees_df.head(5)
# Out:
#    fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# 0    1       426  2017/05/09    PSME  37.4      Fair       105.0        44.0
# 1    2       427  2017/05/09    PSME  32.5      Fair        94.0        49.0
# 2    3       428  2017/05/09    CRLA   9.7      Fair        23.0        28.0
# 3    4       429  2017/05/09    QURU  10.3      Poor        28.0        38.0
# 4    5       430  2017/05/09    PSME  33.2      Fair       102.0        43.0
#
#    CrownWid_1 CollectedB  ...        Genus        Common_nam  \
# 0        57.0      staff  ...  Pseudotsuga       Douglas-fir
# 1        45.0      staff  ...  Pseudotsuga       Douglas-fir
# 2        27.0      staff  ...    Crataegus  Lavalle hawthorn
# 3        31.0      staff  ...      Quercus  northern red oak
# 4        44.0      staff  ...  Pseudotsuga       Douglas-fir
#
#               Genus_spec Functional Size Native Edible Nuisance  \
# 0  Pseudotsuga menziesii         CE    L    Yes    NaN      NaN
# 1  Pseudotsuga menziesii         CE    L    Yes    NaN      NaN
# 2  Crataegus x lavalleei         BD    S     No    NaN      NaN
# 3          Quercus rubra         BD    L     No    NaN      NaN
# 4  Pseudotsuga menziesii         CE    L    Yes    NaN      NaN
#
#                                               Origin  \
# 0  North America - from British Columbia south to...
# 1  North America - from British Columbia south to...
# 2  North America - a hybrid between a Mexican and...
# 3  North America - eastern Canada and eastern USA...
# 4  North America - from British Columbia south to...
#
#                                           Species_fa
# 0  Bracts on cones look like a mouse's feet and t...
# 1  Bracts on cones look like a mouse's feet and t...
# 2  Like most hawthorns, the tree has stout thorns...
# 3  Acorns take two years to mature and are an imp...
# 4  Bracts on cones look like a mouse's feet and t...
#
# [5 rows x 40 columns]

# %% [markdown]
# ##### Question 1: There are 5675 trees of the Quercus or Acer genus.

# %%
# Filter the DataFrame for trees with Genus 'Quercus' or 'Acer'
trees_2 = trees_df[(trees_df['Genus'] == "Quercus") | (trees_df['Genus'] == "Acer")]
trees_2.head(5)

# Find the number of rows in the filtered data frame 
print(len(trees_2))
# Out:
# 5675

# %% [markdown]
# ##### Question 2: There are 124 trees of the Quercus or Acer genus with a DBH larger than 50 inches.

# %%
# Read the CSV file
trees_df = pd.read_csv('/arcgis/home/assignment2/portland_park_trees.csv', sep=",", header=0, encoding="ISO-8859-1")

# Filter the DataFrame for trees with Genus 'Quercus' or 'Acer' and DBH larger than 50 inches
filtered_trees = trees_df[((trees_df['Genus'] == "Quercus") | (trees_df['Genus'] == "Acer")) & (trees_df['DBH'] > 50)]

# Count the number of trees that meet the criteria
number_of_trees = len(filtered_trees)

print(f"Number of trees of the Quercus or Acer genus and have a DBH larger than 50 inches: {number_of_trees}")
# Out:
# Number of trees of the Quercus or Acer genus and have a DBH larger than 50 inches: 124

# %% [markdown]
# ##### Question 3: The genus with the highest mean DBH is Quercus with a mean DBH of 23.57 inches.

# %%
# Filter the DataFrame for the specified genera
trees_3 = trees_df[(trees_df['Genus'] == "Quercus") | (trees_df['Genus'] == "Acer") | (trees_df['Genus'] == "Fraxinus")]

# Group by 'Genus' and calculate mean DBH for each genus
mean_dbh_per_genus = trees_3.groupby('Genus')['DBH'].mean()

# Find the genus with the highest mean DBH
highest_mean_dbh_genus = mean_dbh_per_genus.idxmax()
highest_mean_dbh_value = mean_dbh_per_genus.max()

# Round the highest mean DBH value to two decimal places
rounded_highest_mean_dbh_value = round(highest_mean_dbh_value, 2)

print(f"Genus with the highest mean DBH: {highest_mean_dbh_genus} with a mean DBH of {rounded_highest_mean_dbh_value} inches.")
# Out:
# Genus with the highest mean DBH: Quercus with a mean DBH of 23.57 inches.

# %% [markdown]
# ##### Question 4: There are 20 different species of tree recorded in the Acer genus.

# %%
# Filter the DataFrame for the Acer genus
acer_trees = trees_df[trees_df['Genus'] == "Acer"]

# Count the unique species in the Acer genus
print(acer_trees['Genus_spec'].nunique())
# Out:
# 20

# %% [markdown]
# ##### Question 5:

# %%
worldcities_df = pd.read_csv('/arcgis/home/assignment2/world_cities.csv', sep=",", header=0, encoding="ISO-8859-1")
worldcities_df.head(5)
# Out:
#                  city    country    pop    lat    lon  capital
# 0  'Abasan al-Jadidah  Palestine   5629  31.31  34.34        0
# 1  'Abasan al-Kabirah  Palestine  18999  31.32  34.35        0
# 2        'Abdul Hakim   Pakistan  47788  30.55  72.11        0
# 3  'Abdullah-as-Salam     Kuwait  21817  29.36  47.98        0
# 4               'Abud  Palestine   2456  32.03  35.07        0

# %%
worldcities_df = pd.read_csv('/arcgis/home/assignment2/world_cities.csv', sep=",", header=0, encoding="ISO-8859-1")
worldcities_df.head(5)


# create a new column with population in millions by dividing the original population values by 1,000,000
worldcities_df['pop_M'] = worldcities_df['pop'] / 1000000
worldcities_df.head(5)
# Out:
#                  city    country    pop    lat    lon  capital     pop_M
# 0  'Abasan al-Jadidah  Palestine   5629  31.31  34.34        0  0.005629
# 1  'Abasan al-Kabirah  Palestine  18999  31.32  34.35        0  0.018999
# 2        'Abdul Hakim   Pakistan  47788  30.55  72.11        0  0.047788
# 3  'Abdullah-as-Salam     Kuwait  21817  29.36  47.98        0  0.021817
# 4               'Abud  Palestine   2456  32.03  35.07        0  0.002456

# %%
# remove the original population column 
worldcities_df = worldcities_df.drop(columns=['pop'])
worldcities_df.head(5)
# Out:
#                  city    country    lat    lon  capital     pop_M
# 0  'Abasan al-Jadidah  Palestine  31.31  34.34        0  0.005629
# 1  'Abasan al-Kabirah  Palestine  31.32  34.35        0  0.018999
# 2        'Abdul Hakim   Pakistan  30.55  72.11        0  0.047788
# 3  'Abdullah-as-Salam     Kuwait  29.36  47.98        0  0.021817
# 4               'Abud  Palestine  32.03  35.07        0  0.002456

# %%
# Filter to just include Amsterdam
amsterdam_df = worldcities_df[worldcities_df['city'] == 'Amsterdam']
amsterdam_df.head()
# Out:
#            city      country    lat   lon  capital     pop_M
# 1356  Amsterdam  Netherlands  52.37  4.89        1  0.744159

# %%
# Filter for cities in the Netherlands
netherlands_cities = worldcities_df[worldcities_df['country'] == 'Netherlands']

# Sort the cities by population size in descending order and select the top five
top_5_cities = netherlands_cities.sort_values(by='pop_M', ascending=False).head(5)

# Display the top five cities
top_5_cities.head()
# Out:
#                city      country     pop    lat   lon  capital     pop_M
# 1356      Amsterdam  Netherlands  744159  52.37  4.89        1  0.744159
# 31705     Rotterdam  Netherlands  597481  51.93  4.48        0  0.597481
# 43643  s-Gravenhage  Netherlands  479525  52.07  4.30        0  0.479525
# 39731       Utrecht  Netherlands  280559  52.10  5.11        0  0.280559
# 10243     Eindhoven  Netherlands  211367  51.44  5.47        0  0.211367

# %% [markdown]
# ## Part 3: Python Data Visualisation

# %%
import matplotlib.pyplot as plt

#Change the default plot size.
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8] 

import seaborn as sns

# %%
#use pandas to read the csv file 
trees_df = pd.read_csv('/arcgis/home/assignment2/portland_park_trees.csv', sep=",", header=0, encoding="ISO-8859-1")

# %% [markdown]
# ##### Graph 1:

# %%
#filter the dataframe to just include trees of the genus Ulmus 
ulmus_trees = trees_df[trees_df['Genus'] == 'Ulmus']

# create the scatterplot 
plot = sns.relplot(x=ulmus_trees['DBH'], y=ulmus_trees['TreeHeight'])

# Set the title of the plot
plot.fig.suptitle('Scatterplot of DBH vs Tree Height of the Ulmus genus', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# ##### Graph 2:

# %%
# create a scatterplot with DBH (x-axis), Tree height (y-axis)and the species as the hue 

plot = sns.relplot(x='DBH', y='TreeHeight', hue='Genus_spec', data=ulmus_trees)

# Set the title of the plot
plot.fig.suptitle('Scatterplot of DBH vs Tree Height of the Ulmus genus', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# ##### Graph 3:

# %%
#create a boxplot of DBH differentiated by species 
sns.boxplot(x='Species', y='DBH', data=ulmus_trees)
# Out:
# <AxesSubplot: xlabel='Species', ylabel='DBH'>

# %% [markdown]
# ##### Graph 4:

# %%
# Create a figure with 1 row and 2 columns
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Graph 1: Scatterplot 
sns.scatterplot(x='DBH', y='TreeHeight', data=ulmus_trees, ax=axs[0])
axs[0].set_title('Scatterplot of Ulmus Trees (DBH vs Tree Height)')


# Graph 3: Boxplot 
sns.boxplot(x='Genus_spec', y='DBH', data=ulmus_trees, ax=axs[1])
axs[1].set_title('Boxplot of DBH for Ulmus Species')
axs[1].tick_params(axis='x', rotation=45)  # Rotate x labels for clarity


# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 4: Python GeoPandas

# %% [markdown]
# ##### install packages

# %%
pip install mapclassify
# Out:
# Collecting mapclassify
#   Obtaining dependency information for mapclassify from https://files.pythonhosted.org/packages/3f/f1/8db36df379703311c16e5341b408dad04e34cfded66f38e351c380fbd5ae/mapclassify-2.6.1-py3-none-any.whl.metadata
#   Downloading mapclassify-2.6.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (3.1)
# Collecting numpy>=1.23 (from mapclassify)
#   Obtaining dependency information for numpy>=1.23 from https://files.pythonhosted.org/packages/2f/75/f007cc0e6a373207818bef17f463d3305e9dd380a70db0e523e7660bf21f/numpy-1.26.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.26.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (1.9.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3.post1)
# Collecting tzdata>=2022.1 (from pandas!=1.5.0,>=1.4->mapclassify)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from scikit-learn>=1.0->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn>=1.0->mapclassify) (2.2.0)
# Collecting numpy>=1.23 (from mapclassify)
#   Obtaining dependency information for numpy>=1.23 from https://files.pythonhosted.org/packages/69/1f/c95b1108a9972a52d7b1b63ed8ca70466b59b8c1811bd121f1e667cc45d8/numpy-1.25.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.25.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)
# Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Downloading numpy-1.25.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 43.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: tzdata, numpy, mapclassify
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.3
#     Uninstalling numpy-1.22.3:
#       Successfully uninstalled numpy-1.22.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.0.3 requires opencv-python-headless>=4.1.1, which is not installed.
# fastai 1.0.63 requires nvidia-ml-py3, which is not installed.
# imgaug 0.4.0 requires opencv-python-headless, which is not installed.
# mmdet3d 1.0.0rc5 requires lyft-dataset-sdk, which is not installed.
# mmdet3d 1.0.0rc5 requires plyfile, which is not installed.
# nuscenes-devkit 1.1.3 requires jupyter, which is not installed.
# nuscenes-devkit 1.1.3 requires opencv-python, which is not installed.
# tensorflow-gpu 2.7.0 requires libclang>=9.0.1, which is not installed.
# tensorflow-gpu 2.7.0 requires tensorflow-io-gcs-filesystem>=0.21.0, which is not installed.
# torch-geometric 1.7.2 requires python-louvain, which is not installed.
# mmdet3d 1.0.0rc5 requires networkx<2.3,>=2.2, but you have networkx 3.1 which is incompatible.
# mmdet3d 1.0.0rc5 requires numba==0.53.0, but you have numba 0.57.1 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.25.2 which is incompatible.
# tensorflow-gpu 2.7.0 requires flatbuffers<3.0,>=1.12, but you have flatbuffers 20210226132247 which is incompatible.
# tensorflow-gpu 2.7.0 requires gast<0.5.0,>=0.2.1, but you have gast 0.5.3 which is incompatible.
# tflite-support 0.4.1 requires flatbuffers<2,>=1.12, but you have flatbuffers 20210226132247 which is incompatible.
# Successfully installed mapclassify-2.6.1 numpy-1.25.2 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install contextily
# Out:
# Requirement already satisfied: contextily in /opt/conda/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: geopy in /opt/conda/lib/python3.9/site-packages (from contextily) (2.4.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from contextily) (3.6.0)
# Requirement already satisfied: mercantile in /opt/conda/lib/python3.9/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.9/site-packages (from contextily) (9.4.0)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.9/site-packages (from contextily) (1.2.10)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from contextily) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from contextily) (1.2.0)
# Requirement already satisfied: xyzservices in /opt/conda/lib/python3.9/site-packages (from contextily) (2023.10.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/conda/lib/python3.9/site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (23.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /opt/conda/lib/python3.9/site-packages (from mercantile->contextily) (8.0.4)
# Requirement already satisfied: affine in /opt/conda/lib/python3.9/site-packages (from rasterio->contextily) (2.3.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.9/site-packages (from rasterio->contextily) (23.1.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from rasterio->contextily) (2023.7.22)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.9/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.9/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.9/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from rasterio->contextily) (68.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->contextily) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->contextily) (1.26.16)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/3e/cf/ede993ed7070c5487e6db550aad490178c06eaa48ad26ff5e5263f995fba/geopandas-0.14.1-py3-none-any.whl.metadata
#   Downloading geopandas-0.14.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/lib/python3.9/site-packages (from geopandas) (2.0.2)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/97/0a/b1525be9680369cc06dd288e12c59d24d5798b4afcdcf1b0915836e1caa6/pyproj-3.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pyproj-3.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/lib/python3.9/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: munch in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (1.25.2)
# Downloading geopandas-0.14.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.1 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 69.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyproj, geopandas
# Successfully installed geopandas-0.14.1 pyproj-3.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd
import contextily as ctx
import rasterio as rio
from rasterio import plot

# %%
pip install folium matplotlib mapclassify branca
# Out:
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/a2/1a/37c7ee1bc806d6c32621fecc72c19f6a9f9b4369e5e8f406a7c16d49f031/folium-0.15.0-py2.py3-none-any.whl.metadata
#   Downloading folium-0.15.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: mapclassify in /opt/conda/lib/python3.9/site-packages (2.6.1)
# Collecting branca
#   Obtaining dependency information for branca from https://files.pythonhosted.org/packages/2f/e7/603b136221de923055716d23e3047da71f92e0d8ba2c4517ce49a54fe768/branca-0.7.0-py3-none-any.whl.metadata
#   Downloading branca-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from folium) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (3.1)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.9/site-packages (from mapclassify) (1.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from scikit-learn>=1.0->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn>=1.0->mapclassify) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->folium) (2023.7.22)
# Downloading folium-0.15.0-py2.py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 5.2 MB/s eta 0:00:00
# Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.0 folium-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Task 1:  Read the dataset you download as GeoPandas DataFrame

# %%
# use geopandas to read the shapefile
deprivation = gpd.read_file('/arcgis/home/assignment2/SG_SIMD_2020.shp')
deprivation.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### Task 2: Plot the first 5 and the last 5 sets of records in your selected dataset.

# %%
deprivation.head(5)
# Out:
#     DataZone       DZName         LAName  SAPE2017  WAPE2017  Rankv2  \
# 0  S01006506  Culter - 01  Aberdeen City       894       580    4691
# 1  S01006507  Culter - 02  Aberdeen City       793       470    4862
# 2  S01006508  Culter - 03  Aberdeen City       624       461    5686
# 3  S01006509  Culter - 04  Aberdeen City       537       307    4332
# 4  S01006510  Culter - 05  Aberdeen City       663       415    3913
#
#    Quintilev2  Decilev2  Vigintilv2  Percentv2  ... CrimeRank  HouseNumOC  \
# 0           4         7          14         68  ...    4664.0          87
# 1           4         7          14         70  ...    4602.0          85
# 2           5         9          17         82  ...    4563.5          31
# 3           4         7          13         63  ...    5626.0          42
# 4           3         6          12         57  ...    3885.0          50
#
#    HouseNumNC HouseOCrat  HouseNCrat  HouseRank    Shape_Leng  Shape_Le_1  \
# 0          10        10%          1%     3248.0  11801.872345    0.157628
# 1           4        10%          0%     3486.0   2900.406362    0.037968
# 2           8         5%          1%     5342.0   3468.761949    0.043980
# 3           6         7%          1%     4394.5   1647.461389    0.020651
# 4           7         9%          1%     3736.0   3026.111412    0.040130
#
#    Shape_Area                                           geometry
# 0    0.000650  POLYGON ((-2.27749 57.09526, -2.27644 57.09520...
# 1    0.000033  POLYGON ((-2.27355 57.10448, -2.27333 57.10447...
# 2    0.000040  POLYGON ((-2.27444 57.10170, -2.27238 57.10045...
# 3    0.000014  POLYGON ((-2.26612 57.10132, -2.26599 57.10091...
# 4    0.000027  POLYGON ((-2.26014 57.10159, -2.26051 57.10133...
#
# [5 rows x 53 columns]

# %%
deprivation.tail(5)
# Out:
#        DataZone               DZName        LAName  SAPE2017  WAPE2017  \
# 6971  S01013477  Broxburn South - 06  West Lothian       612       355
# 6972  S01013478   Broxburn East - 01  West Lothian       817       582
# 6973  S01013479   Broxburn East - 02  West Lothian       785       479
# 6974  S01013480   Broxburn East - 03  West Lothian       677       410
# 6975  S01013481   Broxburn East - 04  West Lothian       462       305
#
#       Rankv2  Quintilev2  Decilev2  Vigintilv2  Percentv2  ... CrimeRank  \
# 6971    2464           2         4           8         36  ...    3161.0
# 6972    3681           3         6          11         53  ...    1819.0
# 6973    1423           2         3           5         21  ...     795.0
# 6974    3291           3         5          10         48  ...    5007.0
# 6975    5269           4         8          16         76  ...    2364.0
#
#       HouseNumOC  HouseNumNC HouseOCrat  HouseNCrat  HouseRank    Shape_Leng  \
# 6971          93          10        15%          2%     1671.0   1775.782199
# 6972          87           1        10%          0%     3594.0   2319.192976
# 6973          96           9        12%          1%     2624.0   3234.544766
# 6974         107           1        16%          0%     1865.0   1598.577583
# 6975          67           2        15%          0%     2082.0  13900.390027
#
#       Shape_Le_1  Shape_Area  \
# 6971    0.023189    0.000016
# 6972    0.029404    0.000018
# 6973    0.041514    0.000038
# 6974    0.021329    0.000014
# 6975    0.190560    0.000736
#
#                                                geometry
# 6971  POLYGON ((-3.46323 55.93433, -3.46319 55.93407...
# 6972  POLYGON ((-3.48355 55.93732, -3.48354 55.93728...
# 6973  POLYGON ((-3.46663 55.93627, -3.46652 55.93622...
# 6974  POLYGON ((-3.46259 55.93774, -3.46243 55.93724...
# 6975  POLYGON ((-3.44318 55.93923, -3.44284 55.93908...
#
# [5 rows x 53 columns]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# plot the first 5 records in the dataset 
deprivation.head(5).plot(ax=axs[0], color='blue')
axs[0].set_title('First 5 Records')

# plot the last 5 records in the dataset 
deprivation.tail(5).plot(ax=axs[1], color='red')
axs[1].set_title('Last 5 Records')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Task 3:  Create a map where you can explore the selected dataset

# %%
small_deprivation = deprivation[["DataZone","DZName","LAName","Quintilev2", "CrimeRank", "geometry"]]
small_deprivation.head()
# Out:
#     DataZone       DZName         LAName  Quintilev2  CrimeRank  \
# 0  S01006506  Culter - 01  Aberdeen City           4     4664.0
# 1  S01006507  Culter - 02  Aberdeen City           4     4602.0
# 2  S01006508  Culter - 03  Aberdeen City           5     4563.5
# 3  S01006509  Culter - 04  Aberdeen City           4     5626.0
# 4  S01006510  Culter - 05  Aberdeen City           3     3885.0
#
#                                             geometry
# 0  POLYGON ((-2.27749 57.09526, -2.27644 57.09520...
# 1  POLYGON ((-2.27355 57.10448, -2.27333 57.10447...
# 2  POLYGON ((-2.27444 57.10170, -2.27238 57.10045...
# 3  POLYGON ((-2.26612 57.10132, -2.26599 57.10091...
# 4  POLYGON ((-2.26014 57.10159, -2.26051 57.10133...

# %%
small_deprivation.explore(column='Quintilev2', cmap='RdYlBu')

# ArcGIS will not allow me to save the notebook with this interactive map include and the error 'Request Entity too large' is given, so I have included a screenshot of this map at the end

# %%
deprivation.plot(column="Quintilev2", cmap="RdYlBu")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### Task 4:  the CRS of this data is ESPG:4326

# %%
deprivation.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ##### Task 5: the dataset contains 6976 features

# %%
len(deprivation)
# Out:
# 6976

# %% [markdown]
# ##### Task 6: Define a sub-setting filter to create a new geopandas dataframe where you filter the selected dataset based on a categorical attribute.

# %%
# subset the rows based on the categorical variable 'LA Name'
deprivation2 = deprivation['LAName'] == 'Fife'
deprivation2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6971    False
# 6972    False
# 6973    False
# 6974    False
# 6975    False
# Name: LAName, Length: 6976, dtype: bool

# %%
# pass the series as an index to the GeoDataFrame
fife_deprivation = deprivation[deprivation2]
fife_deprivation.head(5)
# Out:
#        DataZone                           DZName LAName  SAPE2017  WAPE2017  \
# 2758  S01009264  Kincardine North and Tulliallan   Fife       562       355
# 2759  S01009265                  Kincardine West   Fife       750       457
# 2760  S01009266                  Kincardine East   Fife       839       526
# 2761  S01009267                 Kincardine South   Fife       838       513
# 2762  S01009268           Blairhall and Landward   Fife      1025       651
#
#       Rankv2  Quintilev2  Decilev2  Vigintilv2  Percentv2  ... CrimeRank  \
# 2758    5056           4         8          15         73  ...    4290.0
# 2759    2310           2         4           7         34  ...    4472.5
# 2760    3273           3         5          10         47  ...    3521.0
# 2761    4260           4         7          13         62  ...    5194.0
# 2762    3280           3         5          10         48  ...    4790.0
#
#       HouseNumOC  HouseNumNC HouseOCrat  HouseNCrat  HouseRank    Shape_Leng  \
# 2758           8          12         2%          2%     6203.0  26760.205094
# 2759          79           6        10%          1%     3455.0   3651.849197
# 2760          40           0         5%          0%     5918.0   3410.162272
# 2761          54          22         7%          3%     3843.0   3283.946981
# 2762          67           2         7%          0%     4982.0  24155.550170
#
#       Shape_Le_1  Shape_Area  \
# 2758    0.333803    0.003065
# 2759    0.043975    0.000039
# 2760    0.044253    0.000030
# 2761    0.042826    0.000029
# 2762    0.313693    0.002005
#
#                                                geometry
# 2758  POLYGON ((-3.71332 56.10463, -3.71276 56.10459...
# 2759  POLYGON ((-3.72472 56.07510, -3.72376 56.07392...
# 2760  POLYGON ((-3.71158 56.07127, -3.71138 56.07117...
# 2761  POLYGON ((-3.71523 56.06928, -3.71523 56.06898...
# 2762  POLYGON ((-3.62531 56.11131, -3.62457 56.11109...
#
# [5 rows x 53 columns]

# %% [markdown]
# ##### Task 7: Define a sub-setting filter to create a new geopandas dataframe where you filter the selected dataset based on a numerical attribute.

# %%
# subset the rows based on the numerical variable 'Crime Rank'
deprivation3 = deprivation['CrimeRank'] >= 6000
deprivation3
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6971    False
# 6972    False
# 6973    False
# 6974    False
# 6975    False
# Name: CrimeRank, Length: 6976, dtype: bool

# %%
# pass the series as an index to the GeoDataFrame
high_crime = deprivation[deprivation3]
high_crime.head(5)
# Out:
#      DataZone                                     DZName         LAName  \
# 5   S01006511                                Culter - 06  Aberdeen City
# 7   S01006513  Cults, Bieldside and Milltimber West - 01  Aberdeen City
# 9   S01006515  Cults, Bieldside and Milltimber West - 03  Aberdeen City
# 12  S01006518  Cults, Bieldside and Milltimber East - 01  Aberdeen City
# 14  S01006520  Cults, Bieldside and Milltimber East - 03  Aberdeen City
#
#     SAPE2017  WAPE2017  Rankv2  Quintilev2  Decilev2  Vigintilv2  Percentv2  \
# 5        759       453    6253           5         9          18         90
# 7        788       406    6177           5         9          18         89
# 9        816       529    6363           5        10          19         92
# 12       664       370    6674           5        10          20         96
# 14       875       559    6490           5        10          19         94
#
#     ... CrimeRank  HouseNumOC  HouseNumNC HouseOCrat  HouseNCrat  HouseRank  \
# 5   ...    6928.0          27           8         4%          1%     5924.0
# 7   ...    6928.0          15           4         3%          1%     6394.0
# 9   ...    6844.0          29           1         4%          0%     6174.5
# 12  ...    6792.0           2           0         0%          0%     6960.0
# 14  ...    6928.0          12           0         2%          0%     6825.0
#
#       Shape_Leng  Shape_Le_1  Shape_Area  \
# 5    4300.088504    0.058335    0.000059
# 7    4077.119814    0.056620    0.000045
# 9   15374.997633    0.208200    0.000822
# 12   4542.507630    0.062769    0.000077
# 14   2688.803137    0.035725    0.000030
#
#                                              geometry
# 5   POLYGON ((-2.25358 57.10325, -2.25108 57.10233...
# 7   POLYGON ((-2.22117 57.10770, -2.22160 57.10758...
# 9   POLYGON ((-2.23261 57.12057, -2.23298 57.11680...
# 12  POLYGON ((-2.21899 57.11898, -2.21705 57.11884...
# 14  POLYGON ((-2.20640 57.11971, -2.20497 57.11884...
#
# [5 rows x 53 columns]

# %% [markdown]
# ##### Task 8: Plot the new/filtered geopandas dataframe using one of the attributes to create a choropleth map.

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# Plotting the GeoDataFrame
fig, ax = plt.subplots(1, 1, figsize=(10, 6))  # Create a figure and a single axes.
fife_deprivation.plot(column="Quintilev2", cmap="RdYlBu", ax=ax, legend=True)

# Adding a title to the plot
ax.set_title('Scottish Index of Mutiple Deprivation in Fife', fontsize=15)

# Display the plot
plt.show()

# %% [markdown]
# ## Part 5: Python Rasterio

# %% [markdown]
# ##### install packages

# %% [markdown]
# ##### Task 1: read the file as a rasterio dataset

# %%
elev = rio.open('/arcgis/home/assignment2/elev.tif')

# %% [markdown]
# ###### Task 2: The CRS of the elev.tif is ESPG:32617

# %%
print(elev.crs)
# Out:
# EPSG:32617

# %% [markdown]
# ###### Task 3:  Describe the raster dataset regarding the raster extent (bounds), the reference system, and how many bands are in this dataset.

# %%
print(elev.bounds)
print(elev.count)
# Out:
# BoundingBox(left=479753.39945587853, bottom=4170823.2037591375, right=668843.3994558785, top=4347733.203759138)
# 1

# %% [markdown]
# ###### Task 4: Create a plot/map of the raster dataset.

# %%
elev_arr = elev.read(1)
elev_arr
# Out:
# array([[-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        ...,
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768]], dtype=int16)

# %%
image_read_masked = np.ma.masked_array(elev_arr, mask=(elev_arr == 0))

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.imshow(image_read_masked, cmap="gist_gray")

# %%
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

# %%
from rasterio.plot import show

# %%
show(elev, title='Raster Map of the Elevation', cmap='viridis')
# Out:
# <AxesSubplot: title={'center': 'Raster Map of the Elevation'}>

# %% [markdown]
# ###### Task 5:  Create Histograms from the raster.

# %%
import rasterio
from rasterio.plot import show_hist

file_path = '/arcgis/home/assignment2/elev.tif'

# Open the file using rasterio
with rasterio.open(file_path) as dataset:
    # Read the first band of the raster data
    raster = dataset.read(1)

    # Create a histogram of the raster data 
    show_hist(raster, bins=50, lw=0.0, stacked=False, alpha=0.7,
              title="Histogram of Elevation")
